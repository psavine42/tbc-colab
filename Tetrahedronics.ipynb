# %%
from math import sqrt;
import numpy as np;
import matplotlib.pyplot as plt;
from mpl_toolkits.mplot3d import Axes3D;
# %matplotlib notebook
 
#init
frm = np.array([[0,          0,    sqrt(6)/4],
                [sqrt(3)/3,  0,  -sqrt(6)/12],
                [-sqrt(3)/6, 0.5,  -sqrt(6)/12],
                [-sqrt(3)/6, -0.5, -sqrt(6)/12]])
 
    
#methods to make tetrahedrons from a side length (and origin)
#thanks python for not having native multimethod dispatch
def create_tetrahedron_S(side_length):
    origin = [[0, 0, 0]]
    return np.append(origin, scale * frm, axis=0)
    
def create_tetrahedron_OS(side_length, origin):
    return np.append(origin, scale * frm + origin, axis=0) 
    
def plot_tetrahedron(tetra):
    print(tetra)
    fig2 = plt.figure();
    ax2 = fig2.add_subplot(111, projection='3d');
    Axes3D.scatter(ax2, xs=tetra[:,0], ys=tetra[:,1], zs=tetra[:,2]);

    
#test a tetrahedron 
tetra_S = create_tetrahedron_S(2)
plot_tetrahedron(tetra_S)
    
tetra_OS = create_tetrahedron_OS(2, [[1, 2, 0]])
plot_tetrahedron(tetra_OS)
# Out:
# [[ 0.          0.          0.        ]
#  [ 0.          0.          0.61237244]
#  [ 0.57735027  0.         -0.20412415]
#  [-0.28867513  0.5        -0.20412415]
#  [-0.28867513 -0.5        -0.20412415]]
# <img src="data:image/png;base64,..." width="639.9999861283738">
# [[ 1.          2.          0.        ]
#  [ 1.          2.          0.61237244]
#  [ 1.57735027  2.         -0.20412415]
#  [ 0.71132487  2.5        -0.20412415]
#  [ 0.71132487  1.5        -0.20412415]]
# <img src="data:image/png;base64,..." width="639.9999861283738">
